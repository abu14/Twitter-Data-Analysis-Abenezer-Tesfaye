# %%
import pandas as pd 
import numpy as np 
import extract_dataframe
import clean_tweets_dataframe
#from extract_dataframe import *
#from clean_tweets_dataframe import *

# %%
df_twitter = pd.read_json('data/africa_twitter_data.json',lines=True,nrows=5000)
df_twitter.head()
# Out:
#                  created_at                   id               id_str  \
# 0 2022-08-03 20:19:13+00:00  1554924874166149120  1554924874166149120
# 1 2022-08-02 15:24:42+00:00  1554488368347680771  1554488368347680768
# 2 2022-08-02 15:02:35+00:00  1554482802502127621  1554482802502127616
# 3 2022-08-01 13:51:42+00:00  1554102573635932160  1554102573635932160
# 4 2022-07-31 20:02:20+00:00  1553833459440910338  1553833459440910336
#
#                                            full_text  truncated  \
# 0  #Pelosi airplane landed safely in #Taiwan 🇹🇼  ...      False
# 1  Watch the video of the beginning of the Chines...      False
# 2  #Pelosi \n#Taipei \n#taiwan\n#XiJinping \n#Chi...      False
# 3  #HOBIPALOOZA #LaAcademiaExpulsion #WEURO2022 #...      False
# 4  #Pelosi\n#china\nChina Time ✌️ https://t.co/tE...      False
#
#   display_text_range                                           entities  \
# 0           [0, 222]  {'hashtags': [{'text': 'Pelosi', 'indices': [0...
# ...

# %%
#df_full_text = 
pd.set_option('display.max_colwidth',100)
fulltest_list = list(df_twitter['full_text'].head())
fulltest_list
# Out:
# ['#Pelosi airplane landed safely in #Taiwan 🇹🇼  \n1) - Both 🇨🇳 &amp;  🇺🇸 are playing "win win" on financial markets. 2) - Taiwan may be the future Asian   Cuba  3) - 🇺🇸 &amp; 🇨🇳 need an Asian #NATO / #5G\nWhat\'s your thoughts?',
#  'Watch the video of the beginning of the Chinese bombing of Taiwan during Pelosi visit from here : https://t.co/twah6WU4fZ\nــــــــــــــــــــــــــ\n#Pelosi #マツコの知らない世界 #Yediiklim #BadDecisionsTrailer1 #LawnBowls #祝_CALL119_MV900万回 #มากอดกันนะซีพฤกษ์ https://t.co/m4CXfyZRS7',
#  '#Pelosi \n#Taipei \n#taiwan\n#XiJinping \n#China \nOn a verge of another war https://t.co/DuqDiSnWcd',
#  '#HOBIPALOOZA #LaAcademiaExpulsion #WEURO2022 #jhopeAtLollapalooza #SuzukiPakistan #Fantastico #Taiwan #breastfeeding #Kosovo #BORNPINK  strong ✍️💜 https://t.co/GtZeNL24rm',
#  '#Pelosi\n#china\nChina Time ✌️ https://t.co/tEDjzTlszu']

# %%
list(df_twitter['source'].head())
# Out:
# ['<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>']

# %%
def find_screen_name_test(self)->list:
    screen_name = []
    for items in self:
        screen_name.append(items['user']['screen_name'])
    return screen_name

# %%
from extract_dataframe import TweetDfExtractor

twiiter_sample = TweetDfExtractor(df_twitter)
screenames_t = twiiter_sample.find_screen_name()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       1 from extract_dataframe import TweetDfExtractor
#       3 twiiter_sample = TweetDfExtractor(df_twitter)
# ----> 4 screenames_t = twiiter_sample.find_screen_name()
#
# File c:\Users\Dell\Twitter-Data-Analysis-Template\extract_dataframe.py:103, in TweetDfExtractor.find_screen_name(self)
#     101 screen_name = []
#     102 for items in self.tweets_list:
# --> 103     screen_name.append(items['user']['screen_name'])
#     104 return screen_name
#
# TypeError: string indices must be integers, not 'str'

# %%
df_twitter_sample = df_twitter['user'].apply(lambda x: x['screen_name'])

list(df_twitter_sample.head())
# Out:
# ['DzCritical', 'toopsat', 'NassimaLilEmy', 'd_dhayae', 'Mohamme65404115']

# %%
df_twitter_sample = df_twitter['user'].apply(lambda x: x['followers_count'])

list(df_twitter_sample.head())
# Out:
# [318, 764, 64, 60, 39]

# %%
df_twitter_sample = df_twitter['user'].apply(lambda x: x['friends_count'])

list(df_twitter_sample.head())
# Out:
# [373, 144, 47, 463, 206]

# %%
list(df_twitter['created_at'].head())
# Out:
# [Timestamp('2022-08-03 20:19:13+0000', tz='UTC'),
#  Timestamp('2022-08-02 15:24:42+0000', tz='UTC'),
#  Timestamp('2022-08-02 15:02:35+0000', tz='UTC'),
#  Timestamp('2022-08-01 13:51:42+0000', tz='UTC'),
#  Timestamp('2022-07-31 20:02:20+0000', tz='UTC')]

# %%
df_twitter_sample = df_twitter['user'].apply(lambda x: x['statuses_count'])

list(df_twitter_sample.head())
# Out:
# [888, 1597, 2293, 44, 1313]

# %%
list(df_twitter['possibly_sensitive'].head())
# Out:
# [nan, 0.0, 0.0, 0.0, 0.0]

# %%
import json

test_df_twitter = df_twitter.to_json()

with open ('tests/test_df_twitter.json','w',encoding='utf-8') as f:
    json.dump(test_df_twitter,f, ensure_ascii=False, indent=4)

# %%
df_twitter['source'].unique()
# Out:
# array(['<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#        '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#        '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#        '<a href="https://www.notice.com.ng/" rel="nofollow">notice.com.ng</a>',
#        '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#        '<a href="https://www.bobojaytv.com" rel="nofollow">BobojayTV News</a>',
#        '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#        '<a href="http://publicize.wp.com/" rel="nofollow">WordPress.com</a>',
#        '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#        '<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#        '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#        '<a href="https://jokoshq.com" rel="nofollow">Jokoshq</a>',
# ...

# %%
df_africa = pd.read_json('data/Economic_Twitter_Data.json',lines=True,nrows=1000)
df_africa.head()
# Out:
#                  created_at                   id               id_str  \
# 0 2022-04-22 22:20:18+00:00  1517629396575784961  1517629396575784960
# 1 2022-04-22 22:19:16+00:00  1517629134012399616  1517629134012399616
# 2 2022-04-22 22:17:28+00:00  1517628682659106822  1517628682659106816
# 3 2022-04-22 22:17:20+00:00  1517628647892561924  1517628647892561920
# 4 2022-04-22 22:13:15+00:00  1517627621135237127  1517627621135237120
#
#                                                 text  truncated  \
# 0  RT @nikitheblogger: Irre: Annalena Baerbock sa...      False
# 1  RT @sagt_mit: Merkel schaffte es in 1 Jahr 1 M...      False
# 2  RT @Kryptonoun: @WRi007 Pharma in Lebensmittel...      False
# 3  RT @WRi007: Die #Deutschen sind ein braves Vol...      False
# 4  RT @RolandTichy: Baerbock verkündet mal so neb...      False
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# ...

# %%
pd.DataFrame(df_africa.columns)
# Out:
#                             0
# 0                  created_at
# 1                          id
# 2                      id_str
# 3                        text
# 4                   truncated
# 5                    entities
# 6                      source
# 7       in_reply_to_status_id
# 8   in_reply_to_status_id_str
# 9         in_reply_to_user_id
# 10    in_reply_to_user_id_str
# 11    in_reply_to_screen_name
# 12                       user
# 13                        geo
# 14                coordinates
# 15                      place
# 16               contributors
# 17           retweeted_status
# 18            is_quote_status
# 19              retweet_count
# 20             favorite_count
# 21                  favorited
# 22                  retweeted
# 23                       lang
# 24          extended_entities
# 25         possibly_sensitive
# 26           quoted_status_id
# 27       quoted_status_id_str
# 28              quoted_status

# %%
df_africa.head(3).T
# Out:
#                                                                            0  \
# created_at                                         2022-04-22 22:20:18+00:00
# id                                                       1517629396575784961
# id_str                                                   1517629396575784960
# text                       RT @nikitheblogger: Irre: Annalena Baerbock sa...
# truncated                                                              False
# entities                   {'hashtags': [], 'symbols': [], 'user_mentions...
# source                     <a href="http://twitter.com/download/android" ...
# in_reply_to_status_id                                                    NaN
# in_reply_to_status_id_str                                                NaN
# in_reply_to_user_id                                                      NaN
# in_reply_to_user_id_str                                                  NaN
# ...

# %%
df_twitter.head()
# Out:
#                  created_at                   id               id_str  \
# 0 2022-08-03 20:19:13+00:00  1554924874166149120  1554924874166149120
# 1 2022-08-02 15:24:42+00:00  1554488368347680771  1554488368347680768
# 2 2022-08-02 15:02:35+00:00  1554482802502127621  1554482802502127616
# 3 2022-08-01 13:51:42+00:00  1554102573635932160  1554102573635932160
# 4 2022-07-31 20:02:20+00:00  1553833459440910338  1553833459440910336
#
#                                            full_text  truncated  \
# 0  #Pelosi airplane landed safely in #Taiwan 🇹🇼  ...      False
# 1  Watch the video of the beginning of the Chines...      False
# 2  #Pelosi \n#Taipei \n#taiwan\n#XiJinping \n#Chi...      False
# 3  #HOBIPALOOZA #LaAcademiaExpulsion #WEURO2022 #...      False
# 4  #Pelosi\n#china\nChina Time ✌️ https://t.co/tE...      False
#
#   display_text_range                                           entities  \
# 0           [0, 222]  {'hashtags': [{'text': 'Pelosi', 'indices': [0...
# ...

# %%
pd.set_option('display.max_colwidth',550)
df_twitter['user']
# Out:
# 0       {'id': 1183669359396511744, 'id_str': '1183669359396511744', 'name': 'Critical Thinking DZ التفكير النقدي', 'screen_name': 'DzCritical', 'location': 'Algérie', 'description': 'Science, histoire, philosophie, dernières nouvelles, Médias et des idées saines.
# علوم, تاريخ, فلسفة، اخبار الساعة و أفكار.', 'url': 'https://t.co/bKmczKcTmV', 'entities': {'url': {'urls': [{'url': 'https://t.co/bKmczKcTmV', 'expanded_url': 'http://criticalthinkingdz.gmail.com', 'display_url': 'criticalthinkingdz.gmail.com', 'indices': [0, 23]}]}, 'description': {'urls...
# ...

# %%
df_twitter.head(3).T
# Out:
#                                                                            0  \
# created_at                                         2022-08-03 20:19:13+00:00
# id                                                       1554924874166149120
# id_str                                                   1554924874166149120
# full_text                  #Pelosi airplane landed safely in #Taiwan 🇹🇼  ...
# truncated                                                              False
# display_text_range                                                  [0, 222]
# entities                   {'hashtags': [{'text': 'Pelosi', 'indices': [0...
# metadata                   {'iso_language_code': 'en', 'result_type': 're...
# source                     <a href="http://twitter.com/download/android" ...
# in_reply_to_status_id                                                    NaN
# in_reply_to_status_id_str                                                NaN
# ...

# %%
# Since the number of columns are too many, we won't be able to see the entire info. So we can see half at a time.

half = len(df_twitter.columns) // 2

df_twitter.iloc[:, :half].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   created_at                 1000 non-null   datetime64[ns, UTC]
#  1   id                         1000 non-null   int64
#  2   id_str                     1000 non-null   int64
#  3   full_text                  1000 non-null   object
#  4   truncated                  1000 non-null   bool
#  5   display_text_range         1000 non-null   object
#  6   entities                   1000 non-null   object
#  7   metadata                   1000 non-null   object
#  8   source                     1000 non-null   object
#  9   in_reply_to_status_id      103 non-null    float64
#  10  in_reply_to_status_id_str  103 non-null    float64
#  11  in_reply_to_user_id        120 non-null    float64
#  12  in_reply_to_user_id_str    120 non-null    float64
# ...

# %%
df_twitter.iloc[:, half:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   geo                   0 non-null      float64
#  1   coordinates           0 non-null      float64
#  2   place                 107 non-null    object
#  3   contributors          0 non-null      float64
#  4   is_quote_status       1000 non-null   bool
#  5   retweet_count         1000 non-null   int64
#  6   favorite_count        1000 non-null   int64
#  7   favorited             1000 non-null   bool
#  8   retweeted             1000 non-null   bool
#  9   lang                  1000 non-null   object
#  10  extended_entities     631 non-null    object
#  11  possibly_sensitive    763 non-null    float64
#  12  quoted_status_id      37 non-null     float64
#  13  quoted_status_id_str  37 non-null     float64
#  14  quoted_status         37 non-null     object
# ...

# %%
pd.DataFrame(df_twitter.columns)
# Out:
#                             0
# 0                  created_at
# 1                          id
# 2                      id_str
# 3                   full_text
# 4                   truncated
# 5          display_text_range
# 6                    entities
# 7                    metadata
# 8                      source
# 9       in_reply_to_status_id
# 10  in_reply_to_status_id_str
# 11        in_reply_to_user_id
# 12    in_reply_to_user_id_str
# 13    in_reply_to_screen_name
# 14                       user
# 15                        geo
# 16                coordinates
# 17                      place
# 18               contributors
# 19            is_quote_status
# 20              retweet_count
# 21             favorite_count
# 22                  favorited
# 23                  retweeted
# 24                       lang
# 25          extended_entities
# 26         possibly_sensitive
# 27           quoted_status_id
# 28       quoted_status_id_str
# 29              quoted_status

# %%
df_twitter['lang'].value_counts()
# Out:
# lang
# en    1000
# Name: count, dtype: int64
